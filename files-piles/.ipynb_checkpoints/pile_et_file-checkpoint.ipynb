# %% [markdown]
# # Classes Pile et File en Python
#
# Ce notebook explique comment implémenter et utiliser les classes `Pile` et `File` en utilisant le type `list` de Python.

# %% [markdown]
# ## Classe Pile (Stack)
#
# La pile suit le principe "dernier entré, premier sorti" (LIFO - Last In, First Out).

# %%
class Pile:
    def __init__(self):
        self.elements = []

    def empiler(self, element):
        """Empile un élément sur le dessus de la pile."""
        self.elements.append(element)

    def depiler(self):
        """Dépile l'élément du dessus de la pile."""
        if not self.est_vide():
            return self.elements.pop()
        else:
            raise IndexError("La pile est vide.")

    def sommet(self):
        """Retourne l'élément au sommet de la pile sans le retirer."""
        if not self.est_vide():
            return self.elements[-1]
        else:
            raise IndexError("La pile est vide.")

    def est_vide(self):
        """Vérifie si la pile est vide."""
        return len(self.elements) == 0

    def __str__(self):
        return str(self.elements)

# %% [markdown]
# ### Explication de la classe Pile
# - **`__init__`** : Initialise une liste vide pour stocker les éléments de la pile.
# - **`empiler`** : Ajoute un élément au sommet de la pile.
# - **`depiler`** : Retire et retourne l'élément au sommet de la pile. Lance une erreur si la pile est vide.
# - **`sommet`**  : Retourne l'élément au sommet sans le retirer. Lance une erreur si la pile est vide.
# - **`est_vide`** : Vérifie si la pile est vide.

# %% [markdown]
# ## Classe File (Queue)
#
# La file suit le principe "premier entré, premier sorti" (FIFO - First In, First Out).

# %%
class File:
    def __init__(self):
        self.elements = []

    def enfiler(self, element):
        """Ajoute un élément à la fin de la file."""
        self.elements.append(element)

    def defiler(self):
        """Retire l'élément du début de la file."""
        if not self.est_vide():
            return self.elements.pop(0)
        else:
            raise IndexError("La file est vide.")

    def premier(self):
        """Retourne l'élément au début de la file sans le retirer."""
        if not self.est_vide():
            return self.elements[0]
        else:
            raise IndexError("La file est vide.")

    def est_vide(self):
        """Vérifie si la file est vide."""
        return len(self.elements) == 0

    def __str__(self):
        return str(self.elements)

# %% [markdown]
# ### Explication de la classe File
# - **`__init__`** : Initialise une liste vide pour stocker les éléments de la file.
# - **`enfiler`** : Ajoute un élément à la fin de la file.
# - **`defiler`** : Retire et retourne l'élément au début de la file. Lance une erreur si la file est vide.
# - **`premier`** : Retourne l'élément au début sans le retirer. Lance une erreur si la file est vide.
# - **`est_vide`** : Vérifie si la file est vide.

# %% [markdown]
# ## Exemples d'utilisation

# %%
# Exemple d'utilisation de la Pile
ma_pile = Pile()
ma_pile.empiler(1)
ma_pile.empiler(2)
print("Pile avant dépilement:", ma_pile)
print("Élément dépilé:", ma_pile.depiler())
print("Pile après dépilement:", ma_pile)

print()

# Exemple d'utilisation de la File
ma_file = File()
ma_file.enfiler(1)
ma_file.enfiler(2)
print("File avant défiler:", ma_file)
print("Élément défilé:", ma_file.defiler())
print("File après défiler:", ma_file)
# Out:
# Pile avant dépilement: [1, 2]
# Élément dépilé: 2
# Pile après dépilement: [1]
#
# File avant défiler: [1, 2]
# Élément défilé: 1
# File après défiler: [2]
