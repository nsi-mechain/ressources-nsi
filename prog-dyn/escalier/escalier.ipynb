# %% [markdown]
# # Monter les marches
#
# Un enfant veut monter un escalier de `n` marches. À chaque pas, il peut monter soit 1, soit 2 marches.
#
# On veut déterminer de combien de façons différentes il peut monter tout l’escalier.

# %% [markdown]
# ## Étape 1 — Explorer le problème
#
# **Question 1.1** : Lister toutes les façons de monter 1, 2, puis 3 marches.
#
# **Question 1.2** : Donner explicitement les valeurs de f(1), f(2), f(3), f(4).
#
# **Question 1.3** : Quelle relation de récurrence obtient-on ? (Expliquez pourquoi.)

# %%
# Votre réponse ou code ici

# %% [markdown]
# ## Étape 2 — Fonction récursive simple
# **Question 2** : Complétez la fonction récursive ci-dessous, puis testez-la avec différentes valeurs de n.

# %%
def nb_facons(n):
    if n == 0 or n == 1:
        return 1
    # Complétez la ligne suivante pour la récursion
    return ... # à compléter

# Exemple de test
print(nb_facons(5))

# %% [markdown]
# ## Étape 3 — Visualisation des appels récursifs
# **Question 3** : Ajoutez un compteur global pour afficher le nombre d'appels récursifs pour n = 10.

# %%
compteur = 0

def nb_facons_compteur(n):
    global compteur
    compteur ...
    if n == 0 or n == 1:
        return 1
    return ... # à compléter

compteur = 0
print(nb_facons_compteur(10))
print('Nombre d\'appels récursifs :', compteur)

# %% [markdown]
# ## Étape 4 — Optimisation par mémoïsation
# **Question 4** : Complétez la version mémoïsée ci-dessous.

# %%
def nb_facons_memo(n, memo={}):
    if n in memo:
        return memo[n]
    if n == 0 or n == 1:
        memo[n] = 1
    else:
        memo[n] = ... # à compléter
    return memo[n]

# Test
print(nb_facons_memo(30))

# %% [markdown]
# ## Étape 5 — Programmation dynamique itérative
# **Question 5** : Complétez la version itérative (bottom-up) ci-dessous.

# %%
def nb_facons_dp(n):
    dp = [0]*(n+1)
    dp[0] = 1
    if n > 0:
        dp[1] = 1
    for i in range(2, n+1):
        dp[i] = ... # à compléter
    return dp[n]

print(nb_facons_dp(30))

# %% [markdown]
# ## Étape 6 — Optimisation mémoire supplémentaire
# **Question 6** : Complétez la version qui utilise seulement deux variables.

# %%
def nb_facons_optimise(n):
    a, b = 1, 1
    for _ in range(2, n+1):
        a, b = b, ... # à compléter
    return b

print(nb_facons_optimise(30))
